# %%
import cv2
import numpy as np
import torch
import yaml
import sys

# Modify sys.path
# ** 패스 변경 필요
sys.path.insert(0, "./yolov5/") # yolov5 패스지정

# Now import attempt_load
from yolov5.models.experimental import attempt_load

# Load the "custom" YOLOv5 model
# ** 0813 모델: 0812 데이터로 학습, 크기: 640x640
model = attempt_load('./best.pt')

# Initialize the webcam capture
webcam_cap = cv2.VideoCapture(0)

# Load class names from data.yaml
with open('./yolov5/BATCAM-MX-Data-Labeling-1/data.yaml', 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)
    class_names = data['names']

while True:
    # Capture the webcam frame
    ret, webcam_frame = webcam_cap.read()
    
    # Check if frame read is valid
    if not ret:
        print("Failed to grab frame.")
        continue
    
    # Convert the webcam frame from BGR to RGB and reshape for model input
    img = cv2.cvtColor(webcam_frame, cv2.COLOR_BGR2RGB)
    img_tensor = torch.from_numpy(img).float().permute(2, 0, 1).unsqueeze(0) / 255.0
    
    # Pass the frame through the YOLOv5 model
    results = model(img_tensor)

    # Extract tensor from results tuple
    detections = results[0]

    # Assuming there's a confidence threshold you want to apply
    conf_thresh = 0.6

    # Use the confidence score to filter out weak detections
    mask = detections[0, :, 4] > conf_thresh

    # Extract the boxes, scores, and classes from the detections
    boxes = detections[0, mask, :4].cpu().numpy()
    scores = detections[0, mask, 4].cpu().numpy()
    classes = detections[0, mask, 5].cpu().numpy().astype(np.int32)

    # Draw the bounding boxes and labels on the frame
    for box, score, class_idx in zip(boxes, scores, classes):
        x1, y1, x2, y2 = map(int, box)
        class_name = class_names[class_idx]
        cv2.rectangle(webcam_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(webcam_frame, f"{class_name}: {score:.2f}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        
        # Print the coordinates of the detected object
        print(f"{class_name} coordinates: ({x1}, {y1}), ({x2}, {y2})")

    # Display the frame on the screen
    cv2.imshow('Webcam Capture', webcam_frame)

    # Exit the program if the user presses the 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close the window
webcam_cap.release()
cv2.destroyAllWindows()
# Out:
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# Flange coordinates: (104, 228), (47, 50)
# Flange coordinates: (102, 229), (52, 49)
# Flange coordinates: (101, 231), (51, 47)
# Flange coordinates: (102, 229), (49, 46)
# Flange coordinates: (102, 230), (49, 47)
# Flange coordinates: (364, 380), (79, 40)
# Flange coordinates: (105, 230), (51, 50)
# Flange coordinates: (365, 382), (84, 40)
# Flange coordinates: (103, 230), (56, 48)
# Flange coordinates: (364, 381), (83, 40)
# Flange coordinates: (364, 379), (77, 37)
# Flange coordinates: (364, 381), (93, 38)
# Flange coordinates: (104, 230), (50, 41)
# Flange coordinates: (104, 231), (50, 42)
# Flange coordinates: (362, 382), (72, 38)
# Flange coordinates: (363, 381), (72, 36)
# Flange coordinates: (363, 380), (79, 39)
# Flange coordinates: (105, 229), (50, 49)
# Flange coordinates: (365, 383), (84, 39)
# Flange coordinates: (362, 379), (81, 38)
# Flange coordinates: (214, 216), (53, 47)
# Flange coordinates: (103, 230), (55, 48)
# Flange coordinates: (364, 382), (82, 39)
# Flange coordinates: (364, 379), (77, 37)
# Flange coordinates: (364, 382), (92, 37)
# Flange coordinates: (363, 380), (84, 35)
# Flange coordinates: (104, 230), (49, 41)
# Flange coordinates: (104, 231), (49, 41)
# Flange coordinates: (362, 382), (72, 36)
# Flange coordinates: (363, 382), (72, 35)
# Flange coordinates: (363, 380), (79, 40)
# Flange coordinates: (105, 229), (51, 50)
# Flange coordinates: (364, 382), (84, 41)
# Flange coordinates: (362, 379), (81, 39)
# Flange coordinates: (215, 216), (51, 47)
# Flange coordinates: (103, 230), (55, 48)
# Flange coordinates: (364, 381), (83, 42)
# Flange coordinates: (363, 379), (78, 40)
# Flange coordinates: (363, 379), (77, 39)
# Flange coordinates: (364, 381), (90, 39)
# Flange coordinates: (362, 379), (81, 37)
# Flange coordinates: (102, 231), (51, 42)
# Flange coordinates: (104, 229), (49, 41)
# Flange coordinates: (103, 230), (49, 42)
# Flange coordinates: (362, 382), (74, 40)
# Flange coordinates: (363, 381), (73, 39)
# Flange coordinates: (363, 380), (77, 39)
# Flange coordinates: (105, 229), (51, 49)
# Flange coordinates: (364, 382), (81, 40)
# Flange coordinates: (361, 379), (79, 39)
# Flange coordinates: (102, 229), (55, 47)
# Flange coordinates: (363, 381), (79, 40)
# Flange coordinates: (363, 379), (75, 38)
# Flange coordinates: (363, 381), (87, 38)
# Flange coordinates: (362, 379), (80, 37)
# Flange coordinates: (102, 231), (51, 40)
# Flange coordinates: (103, 229), (49, 39)
# Flange coordinates: (103, 230), (49, 40)
# Flange coordinates: (361, 382), (72, 38)
# Flange coordinates: (362, 381), (71, 37)
# Flange coordinates: (104, 229), (52, 49)
# Flange coordinates: (104, 228), (50, 49)
# Flange coordinates: (360, 380), (76, 38)
# Flange coordinates: (101, 229), (56, 44)
# Flange coordinates: (102, 229), (54, 47)
# Flange coordinates: (361, 380), (74, 36)
# Flange coordinates: (360, 380), (78, 37)
# Flange coordinates: (101, 230), (50, 40)
# Flange coordinates: (103, 228), (48, 39)
# Flange coordinates: (103, 229), (48, 41)
# Flange coordinates: (361, 382), (69, 34)
# Flange coordinates: (103, 229), (52, 51)
# Flange coordinates: (104, 228), (49, 51)
# Flange coordinates: (362, 383), (79, 38)
# Flange coordinates: (360, 379), (78, 39)
# Flange coordinates: (101, 229), (56, 46)
# Flange coordinates: (102, 229), (53, 49)
# Flange coordinates: (362, 379), (75, 37)
# Flange coordinates: (361, 382), (85, 38)
# Flange coordinates: (360, 380), (79, 38)
# Flange coordinates: (101, 230), (51, 43)
# Flange coordinates: (103, 228), (49, 42)
# Flange coordinates: (103, 229), (49, 44)
# Flange coordinates: (360, 383), (71, 37)
# Flange coordinates: (361, 382), (69, 36)
# Flange coordinates: (103, 229), (52, 53)
# Flange coordinates: (101, 230), (47, 53)
# Flange coordinates: (103, 228), (49, 52)
# Flange coordinates: (362, 382), (79, 39)
# Flange coordinates: (361, 379), (78, 40)
# Flange coordinates: (101, 229), (56, 48)
# Flange coordinates: (102, 229), (53, 51)
# Flange coordinates: (362, 381), (77, 39)
# Flange coordinates: (362, 379), (75, 38)
# Flange coordinates: (101, 228), (46, 55)
# Flange coordinates: (361, 381), (84, 39)
# Flange coordinates: (361, 380), (78, 38)
# Flange coordinates: (101, 230), (52, 45)
# Flange coordinates: (103, 228), (50, 44)
# Flange coordinates: (102, 229), (50, 47)
# Flange coordinates: (361, 382), (71, 37)
# Flange coordinates: (361, 381), (70, 37)
# Flange coordinates: (103, 229), (53, 53)
# Flange coordinates: (101, 230), (47, 53)
# Flange coordinates: (103, 228), (49, 52)
# Flange coordinates: (361, 379), (77, 39)
# Flange coordinates: (101, 229), (57, 49)
# Flange coordinates: (101, 229), (51, 50)
# Flange coordinates: (101, 229), (53, 52)
# Flange coordinates: (362, 379), (75, 36)
# Flange coordinates: (101, 228), (47, 55)
# Flange coordinates: (101, 230), (52, 45)
# Flange coordinates: (102, 228), (50, 44)
# Flange coordinates: (102, 229), (50, 47)
# Flange coordinates: (361, 382), (69, 35)
# Flange coordinates: (101, 231), (50, 53)
# Flange coordinates: (102, 228), (52, 54)
# Flange coordinates: (101, 229), (46, 54)
# Flange coordinates: (102, 227), (48, 53)
# Flange coordinates: (363, 382), (78, 38)
# Flange coordinates: (361, 379), (77, 39)
# Flange coordinates: (100, 228), (56, 50)
# Flange coordinates: (101, 229), (50, 51)
# Flange coordinates: (101, 228), (52, 52)
# Flange coordinates: (362, 382), (77, 39)
# Flange coordinates: (362, 379), (74, 38)
# Flange coordinates: (101, 228), (46, 56)
# Flange coordinates: (362, 382), (83, 38)
# Flange coordinates: (361, 380), (78, 38)
# Flange coordinates: (100, 229), (53, 47)
# Flange coordinates: (102, 228), (50, 46)
# Flange coordinates: (101, 228), (50, 48)
# Flange coordinates: (361, 383), (70, 37)
# Flange coordinates: (361, 381), (70, 36)
# Flange coordinates: (363, 380), (77, 38)
# Flange coordinates: (101, 228), (50, 51)
# Flange coordinates: (100, 229), (44, 51)
# Flange coordinates: (102, 227), (45, 51)
# Flange coordinates: (363, 383), (78, 37)
# Flange coordinates: (362, 379), (77, 39)
# Flange coordinates: (99, 228), (54, 47)
# Flange coordinates: (101, 229), (49, 48)
# Flange coordinates: (100, 228), (50, 50)
# Flange coordinates: (363, 382), (77, 38)
# Flange coordinates: (363, 379), (75, 37)
# Flange coordinates: (362, 382), (83, 37)
# Flange coordinates: (362, 380), (78, 37)
# Flange coordinates: (100, 229), (51, 44)
# Flange coordinates: (101, 228), (48, 43)
# Flange coordinates: (101, 228), (49, 46)
# Flange coordinates: (362, 383), (70, 35)
# Flange coordinates: (362, 382), (69, 35)
# Flange coordinates: (100, 229), (44, 50)
# Flange coordinates: (101, 227), (45, 50)
# Flange coordinates: (99, 228), (54, 46)
# Flange coordinates: (100, 229), (49, 47)
# Flange coordinates: (100, 228), (50, 49)
# Flange coordinates: (361, 381), (69, 35)
# Flange coordinates: (363, 379), (76, 39)
# Flange coordinates: (100, 229), (44, 51)
# Flange coordinates: (101, 227), (45, 51)
# Flange coordinates: (363, 382), (78, 39)
# Flange coordinates: (361, 379), (77, 39)
# Flange coordinates: (99, 228), (53, 47)
# Flange coordinates: (100, 229), (49, 48)
# Flange coordinates: (99, 228), (50, 50)
# Flange coordinates: (363, 381), (77, 40)
# Flange coordinates: (362, 379), (74, 38)
# Flange coordinates: (362, 381), (83, 39)
# Flange coordinates: (361, 379), (77, 38)
# Flange coordinates: (100, 228), (49, 46)
# Flange coordinates: (361, 382), (71, 37)
# Flange coordinates: (362, 381), (70, 37)
# Flange coordinates: (363, 379), (76, 39)
# Flange coordinates: (101, 227), (43, 48)
# Flange coordinates: (363, 381), (78, 39)
# Flange coordinates: (361, 379), (77, 39)
# Flange coordinates: (99, 228), (50, 47)
# Flange coordinates: (363, 380), (76, 39)
# Flange coordinates: (362, 379), (73, 38)
# Flange coordinates: (362, 380), (83, 39)
# Flange coordinates: (361, 379), (77, 38)
# Flange coordinates: (361, 381), (72, 37)
# Flange coordinates: (361, 380), (70, 37)
# Flange coordinates: (101, 227), (45, 49)
# Flange coordinates: (363, 382), (78, 37)
# Flange coordinates: (361, 379), (77, 39)
# Flange coordinates: (99, 228), (51, 47)
# Flange coordinates: (362, 381), (77, 38)
# Flange coordinates: (362, 379), (74, 36)
# Flange coordinates: (362, 381), (84, 37)
# Flange coordinates: (361, 379), (78, 37)
# Flange coordinates: (361, 382), (71, 36)
# Flange coordinates: (361, 380), (69, 36)
# Flange coordinates: (102, 228), (48, 51)
# Flange coordinates: (363, 382), (77, 37)
# Flange coordinates: (99, 228), (54, 49)
# Flange coordinates: (362, 379), (73, 36)
# Flange coordinates: (361, 382), (71, 35)
# Flange coordinates: (361, 381), (69, 35)
# Flange coordinates: (363, 380), (78, 40)
# Flange coordinates: (363, 379), (77, 40)
# Flange coordinates: (362, 378), (74, 38)
# Flange coordinates: (362, 380), (84, 39)
# Flange coordinates: (363, 380), (71, 42)
# Flange coordinates: (361, 380), (72, 38)
# Flange coordinates: (361, 379), (71, 38)
# Flange coordinates: (362, 379), (75, 40)
# Flange coordinates: (363, 381), (77, 42)
# Flange coordinates: (362, 379), (75, 41)
# Flange coordinates: (361, 379), (75, 41)
# Flange coordinates: (363, 380), (76, 42)
# Flange coordinates: (362, 379), (73, 39)
# Flange coordinates: (362, 379), (72, 40)
# Flange coordinates: (362, 380), (81, 42)
# Flange coordinates: (361, 379), (76, 41)
# Flange coordinates: (364, 380), (70, 45)
# Flange coordinates: (361, 380), (71, 41)
# Flange coordinates: (362, 379), (71, 41)
# Flange coordinates: (362, 379), (75, 41)
# Flange coordinates: (362, 381), (76, 41)
# Flange coordinates: (361, 379), (75, 41)
# Flange coordinates: (362, 380), (75, 42)
# Flange coordinates: (362, 378), (72, 39)
# Flange coordinates: (362, 378), (72, 40)
# Flange coordinates: (361, 380), (80, 41)
# Flange coordinates: (360, 379), (76, 40)
# Flange coordinates: (363, 380), (69, 44)
# Flange coordinates: (361, 380), (70, 40)
# Flange coordinates: (361, 379), (70, 40)
# Flange coordinates: (362, 379), (76, 41)
# Flange coordinates: (363, 382), (77, 41)
# Flange coordinates: (361, 379), (76, 41)
# Flange coordinates: (362, 381), (76, 41)
# Flange coordinates: (362, 379), (73, 39)
# Flange coordinates: (362, 381), (82, 40)
# Flange coordinates: (361, 379), (77, 39)
# Flange coordinates: (363, 381), (70, 43)
# Flange coordinates: (361, 381), (71, 40)
# Flange coordinates: (361, 380), (71, 39)
# Flange coordinates: (362, 379), (75, 40)
# Flange coordinates: (363, 382), (76, 41)
# Flange coordinates: (361, 379), (75, 41)
# Flange coordinates: (362, 381), (75, 41)
# Flange coordinates: (362, 379), (72, 38)
# Flange coordinates: (362, 379), (72, 39)
# Flange coordinates: (362, 381), (81, 40)
# Flange coordinates: (361, 379), (76, 39)
# Flange coordinates: (361, 382), (70, 39)
# Flange coordinates: (361, 380), (70, 39)
# Flange coordinates: (362, 380), (75, 40)
# Flange coordinates: (363, 382), (76, 40)
# Flange coordinates: (361, 379), (74, 40)
# Flange coordinates: (362, 381), (75, 40)
# Flange coordinates: (362, 379), (72, 37)
# Flange coordinates: (362, 381), (81, 40)
# Flange coordinates: (361, 379), (75, 39)
# Flange coordinates: (361, 381), (69, 39)
# Flange coordinates: (362, 380), (70, 38)
# Flange coordinates: (362, 379), (76, 41)
# Flange coordinates: (363, 382), (77, 41)
# Flange coordinates: (361, 379), (76, 41)
# Flange coordinates: (362, 381), (76, 42)
# Flange coordinates: (362, 379), (73, 39)
# Flange coordinates: (362, 379), (73, 39)
# Flange coordinates: (362, 381), (82, 41)
# Flange coordinates: (361, 379), (77, 40)
# Flange coordinates: (363, 381), (70, 43)
# Flange coordinates: (361, 381), (71, 40)
# Flange coordinates: (362, 380), (71, 40)
# Flange coordinates: (363, 381), (77, 41)
# Flange coordinates: (362, 380), (76, 41)
# Flange coordinates: (362, 379), (72, 38)
# Flange coordinates: (362, 380), (82, 42)
# Flange coordinates: (361, 381), (70, 40)
# Flange coordinates: (361, 380), (70, 39)
# Flange coordinates: (363, 382), (77, 40)
# Flange coordinates: (361, 379), (75, 40)
# Flange coordinates: (362, 381), (76, 40)
# Flange coordinates: (362, 379), (72, 38)
# Flange coordinates: (362, 381), (82, 40)
# Flange coordinates: (361, 380), (77, 38)
# Flange coordinates: (361, 382), (70, 39)
# Flange coordinates: (361, 380), (70, 38)
# Flange coordinates: (363, 382), (76, 39)
# Flange coordinates: (361, 379), (75, 39)
# Flange coordinates: (362, 381), (75, 40)
# Flange coordinates: (362, 379), (72, 37)
# Flange coordinates: (362, 381), (82, 39)
# Flange coordinates: (361, 382), (69, 38)
# Flange coordinates: (362, 380), (69, 37)
# Flange coordinates: (362, 380), (74, 40)
# Flange coordinates: (363, 382), (75, 40)
# Flange coordinates: (361, 379), (75, 40)
# Flange coordinates: (362, 381), (75, 41)
# Flange coordinates: (362, 379), (71, 39)
# Flange coordinates: (362, 381), (80, 40)
# Flange coordinates: (361, 380), (76, 39)
# Flange coordinates: (361, 382), (70, 39)
# Flange coordinates: (361, 381), (70, 38)
# Flange coordinates: (362, 379), (75, 40)
# Flange coordinates: (363, 381), (77, 40)
# Flange coordinates: (361, 379), (75, 40)
# Flange coordinates: (362, 380), (75, 41)
# Flange coordinates: (362, 379), (72, 38)
# Flange coordinates: (362, 380), (82, 40)
# Flange coordinates: (361, 379), (76, 39)
# Flange coordinates: (361, 381), (70, 39)
# Flange coordinates: (362, 380), (70, 39)
# Flange coordinates: (362, 382), (77, 39)
# Flange coordinates: (361, 379), (75, 40)
# Flange coordinates: (362, 381), (76, 40)
# Flange coordinates: (362, 379), (73, 37)
# Flange coordinates: (361, 381), (82, 40)
# Flange coordinates: (361, 382), (70, 38)
# Flange coordinates: (362, 381), (70, 37)
# Flange coordinates: (363, 383), (78, 39)
# Flange coordinates: (362, 380), (76, 39)
# Flange coordinates: (363, 382), (77, 39)
# Flange coordinates: (363, 379), (74, 38)
# Flange coordinates: (362, 382), (83, 39)
# Flange coordinates: (362, 380), (78, 38)
# Flange coordinates: (361, 383), (69, 37)
# Flange coordinates: (362, 382), (69, 37)
# Flange coordinates: (363, 380), (76, 38)
# Flange coordinates: (363, 383), (77, 38)
# Flange coordinates: (362, 380), (75, 39)
# Flange coordinates: (363, 382), (76, 38)
# Flange coordinates: (363, 379), (73, 37)
# Flange coordinates: (362, 382), (82, 38)
# Flange coordinates: (362, 380), (77, 38)
# Flange coordinates: (361, 383), (69, 36)
# Flange coordinates: (362, 382), (69, 35)
# Flange coordinates: (362, 383), (77, 39)
# Flange coordinates: (361, 379), (76, 39)
# Flange coordinates: (362, 382), (76, 39)
# Flange coordinates: (362, 379), (73, 38)
# Flange coordinates: (362, 382), (82, 39)
# Flange coordinates: (361, 380), (76, 39)
# Flange coordinates: (361, 383), (70, 37)
# Flange coordinates: (361, 381), (70, 37)
# Flange coordinates: (362, 382), (78, 40)
# Flange coordinates: (361, 379), (76, 40)
# Flange coordinates: (362, 381), (77, 40)
# Flange coordinates: (362, 379), (74, 38)
# Flange coordinates: (362, 381), (83, 40)
# Flange coordinates: (361, 382), (70, 39)
# Flange coordinates: (362, 381), (70, 38)
# Flange coordinates: (363, 380), (76, 39)
# Flange coordinates: (363, 383), (77, 39)
# Flange coordinates: (361, 379), (76, 39)
# Flange coordinates: (363, 382), (77, 39)
# Flange coordinates: (363, 379), (74, 37)
# Flange coordinates: (362, 382), (83, 39)
# Flange coordinates: (362, 380), (76, 39)
# Flange coordinates: (361, 383), (70, 38)
# Flange coordinates: (362, 382), (70, 37)
# Flange coordinates: (363, 380), (76, 39)
# Flange coordinates: (363, 383), (78, 40)
# Flange coordinates: (362, 379), (76, 41)
# Flange coordinates: (363, 382), (77, 40)
# Flange coordinates: (363, 379), (74, 39)
# Flange coordinates: (362, 382), (82, 40)
# Flange coordinates: (362, 380), (76, 40)
# Flange coordinates: (362, 383), (70, 39)
# Flange coordinates: (362, 382), (70, 39)
# Flange coordinates: (363, 380), (77, 38)
# Flange coordinates: (363, 383), (78, 39)
# Flange coordinates: (362, 379), (78, 39)
# Flange coordinates: (363, 382), (78, 39)
# Flange coordinates: (363, 379), (75, 38)
# Flange coordinates: (362, 382), (83, 38)
# Flange coordinates: (362, 380), (78, 38)
# Flange coordinates: (362, 383), (70, 37)
# Flange coordinates: (362, 382), (71, 37)
# Flange coordinates: (363, 380), (77, 39)
# Flange coordinates: (363, 382), (79, 40)
# Flange coordinates: (362, 379), (77, 40)
# Flange coordinates: (363, 382), (78, 40)
# Flange coordinates: (363, 379), (74, 39)
# Flange coordinates: (362, 382), (84, 40)
# Flange coordinates: (362, 380), (77, 40)
# Flange coordinates: (361, 383), (71, 39)
# Flange coordinates: (362, 381), (70, 39)
# Flange coordinates: (363, 383), (77, 39)
# Flange coordinates: (362, 380), (76, 40)
# Flange coordinates: (363, 382), (77, 39)
# Flange coordinates: (363, 379), (74, 38)
# Flange coordinates: (362, 382), (82, 39)
# Flange coordinates: (362, 380), (77, 39)
# Flange coordinates: (361, 383), (70, 37)
# Flange coordinates: (362, 382), (69, 37)
