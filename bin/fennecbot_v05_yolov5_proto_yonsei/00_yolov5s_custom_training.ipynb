# %%
from roboflow import Roboflow
rf = Roboflow(api_key="kyeBQF5BR2jWkdnPBLxu")
project = rf.workspace("fennecbot-yonsei").project("fennecbot_0812")
dataset = project.version(3).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to FennecBot_0812-3 in yolov5pytorch:: 100%|█████████████████████████████████████████████████████████| 630/630 [00:00<00:00, 4931.43it/s]

# %%
# YOLOv5 레퍼지토리 다운로드, Yolo 깃허브에서 checkpoint .pt 다운로드 (수동)
! git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15921, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 15921 (delta 15), reused 22 (delta 9), pack-reused 15880
# Receiving objects: 100% (15921/15921), 14.60 MiB | 9.67 MiB/s, done.
# Resolving deltas: 100% (10914/10914), done.

# %%
# !python ./yolov5/train.py --img 640 --batch 16 --epochs 100 --data ./yolov5/FennecBot_0812-3/data.yaml --weights ./yolov5/models/yolov5s.pt
# Out:
# train: weights=./yolov5/models/yolov5s.pt, cfg=, data=./yolov5/FennecBot_0812-3/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.8.17 torch-2.0.1+cu117 CUDA:0 (Tesla V100-DGXS-32GB, 32508MiB)
#
# ...
